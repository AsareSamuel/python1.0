# %% [markdown]
# # Python Project - Data Cleaning for Movies Dataset
# ## by Asare Samuel
#
# ## Introduction
# >  ### The movies dataset is a popular dataset on the internet. It contains fields such as movies,year,genre, rating,year it was produced and movie gross earnings.This project is to clean the data, getting it ready for Visualization.
# ### First import our pandas library, to help us read in our csv file.

# %%
pd.read_csv('movies.csv')
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# >  ### After our CSV file is read in, we assign it to an alias(df) to make future readings easier.

# %%
df=pd.read_csv('movies.csv')

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# ### CLEANING

# %% [markdown]
# > ### The first cleaning operation is to get rid of all duplicate rows in our table. We have to write code to actually figure out if we have duplicate rows.

# %%
df.MOVIES.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# Name: MOVIES, Length: 9999, dtype: bool

# %%
sum(df.MOVIES.duplicated())
# Out:
# 3182

# %%
df.drop_duplicates('MOVIES',inplace=True)

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9935                       The Imperfects     (2021– )
# 9964            AlRawabi School for Girls       (2021)
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# > ### Reset the index to have columns in the right order.

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 6812                       The Imperfects     (2021– )
# 6813            AlRawabi School for Girls       (2021)
# 6814                            Totenfrau     (2022– )
# 6815                               Arcane     (2021– )
# 6816                    Heart of Invictus     (2022– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# > ### Make all column names lowercase to make them easy to work with

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#                                    movies         year  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 6812                       The Imperfects     (2021– )
# 6813            AlRawabi School for Girls       (2021)
# 6814                            Totenfrau     (2022– )
# 6815                               Arcane     (2021– )
# 6816                    Heart of Invictus     (2022– )
#
#                                            genre  rating  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# > ### Extract only the year from the year column

# %%
df.year.str.extract('(\d{4})')
# Out:
#          0
# 0     2021
# 1     2021
# 2     2010
# 3     2013
# 4     2021
# ...    ...
# 6812  2021
# 6813  2021
# 6814  2022
# 6815  2021
# 6816  2022
#
# [6817 rows x 1 columns]

# %%
df.year=df.year.str.extract('(\d{4})')

# %%
df
# Out:
#                                    movies  year  \
# 0                           Blood Red Sky  2021
# 1     Masters of the Universe: Revelation  2021
# 2                        The Walking Dead  2010
# 3                          Rick and Morty  2013
# 4                         Army of Thieves  2021
# ...                                   ...   ...
# 6812                       The Imperfects  2021
# 6813            AlRawabi School for Girls  2021
# 6814                            Totenfrau  2022
# 6815                               Arcane  2021
# 6816                    Heart of Invictus  2022
#
#                                            genre  rating  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...

# %% [markdown]
# > ### Extract the first genre from the genre column. First split the column using the commma delimiter.

# %%
df.genre.str.split(',',expand=True)
# Out:
#                         0                      1                       2
# 0                \nAction                 Horror    Thriller
# 1             \nAnimation                 Action   Adventure
# 2                 \nDrama                 Horror    Thriller
# 3             \nAnimation              Adventure      Comedy
# 4                \nAction                  Crime      Horror
# ...                   ...                    ...                     ...
# 6812          \nAdventure                  Drama     Fantasy
# 6813  \nDrama                               None                    None
# 6814              \nDrama   Thriller                                None
# 6815          \nAnimation                 Action   Adventure
# 6816        \nDocumentary      Sport                                None
#
# [6817 rows x 3 columns]

# %% [markdown]
# > ### Select the first cloumn using indexing

# %%
df.genre.str.split(',',expand=True)[0]
# Out:
# 0                  \nAction
# 1               \nAnimation
# 2                   \nDrama
# 3               \nAnimation
# 4                  \nAction
#                ...
# 6812            \nAdventure
# 6813    \nDrama
# 6814                \nDrama
# 6815            \nAnimation
# 6816          \nDocumentary
# Name: 0, Length: 6817, dtype: object

# %% [markdown]
# > ### Get rid of unwanted characters infront of the genres

# %%
df.genre=df.genre.str.split(',',expand=True)[0].str[1:]

# %%
df
# Out:
#                                    movies  year              genre  rating  \
# 0                           Blood Red Sky  2021             Action     6.1
# 1     Masters of the Universe: Revelation  2021          Animation     5.0
# 2                        The Walking Dead  2010              Drama     8.2
# 3                          Rick and Morty  2013          Animation     9.2
# 4                         Army of Thieves  2021             Action     NaN
# ...                                   ...   ...                ...     ...
# 6812                       The Imperfects  2021          Adventure     NaN
# 6813            AlRawabi School for Girls  2021  Drama                 NaN
# 6814                            Totenfrau  2022              Drama     NaN
# 6815                               Arcane  2021          Animation     NaN
# 6816                    Heart of Invictus  2022        Documentary     NaN
#
#                                                one-line  \
# ...

# %%
df.head(3)
# Out:
#                                 movies  year      genre  rating  \
# 0                        Blood Red Sky  2021     Action     6.1
# 1  Masters of the Universe: Revelation  2021  Animation     5.0
# 2                     The Walking Dead  2010      Drama     8.2
#
#                                             one-line  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
#
#                                                stars    votes  runtime gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0   NaN
# 1  \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0   NaN
# 2  \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0   NaN

# %%
df.drop('one-line',axis=1,inplace=True)

# %%
df
# Out:
#                                    movies  year              genre  rating  \
# 0                           Blood Red Sky  2021             Action     6.1
# 1     Masters of the Universe: Revelation  2021          Animation     5.0
# 2                        The Walking Dead  2010              Drama     8.2
# 3                          Rick and Morty  2013          Animation     9.2
# 4                         Army of Thieves  2021             Action     NaN
# ...                                   ...   ...                ...     ...
# 6812                       The Imperfects  2021          Adventure     NaN
# 6813            AlRawabi School for Girls  2021  Drama                 NaN
# 6814                            Totenfrau  2022              Drama     NaN
# 6815                               Arcane  2021          Animation     NaN
# 6816                    Heart of Invictus  2022        Documentary     NaN
#
# ...

# %% [markdown]
# > ### Only show the stars of the movie and nothing else from the stars column.

# %%
df.stars=df.stars.str.split('Stars',expand=True)[1].str.replace('\n','').str.replace(':','')

# %%
df
# Out:
#                                    movies  year              genre  rating  \
# 0                           Blood Red Sky  2021             Action     6.1
# 1     Masters of the Universe: Revelation  2021          Animation     5.0
# 2                        The Walking Dead  2010              Drama     8.2
# 3                          Rick and Morty  2013          Animation     9.2
# 4                         Army of Thieves  2021             Action     NaN
# ...                                   ...   ...                ...     ...
# 6812                       The Imperfects  2021          Adventure     NaN
# 6813            AlRawabi School for Girls  2021  Drama                 NaN
# 6814                            Totenfrau  2022              Drama     NaN
# 6815                               Arcane  2021          Animation     NaN
# 6816                    Heart of Invictus  2022        Documentary     NaN
#
# ...

# %% [markdown]
# > ### Save the file to csv

# %%
df.to_csv('my_cleaned_movies_dataset.csv',index=False)
